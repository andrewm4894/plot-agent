# %% [markdown]
# Plots can be viewed through NBViewer here: https://nbviewer.org/github/andrewm4894/plot-agent/blob/main/examples/example_0.ipynb

# %%
import pandas as pd
import numpy as np
from plot_agent.agent import PlotAgent


# generate a random time series dataframe with 1000 rows
data = {
    'date': pd.date_range(start='2023-01-01', periods=1000),
    'sales': np.random.randint(100, 1000, size=1000),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=1000),
    'product': np.random.choice(['A', 'B', 'C'], size=1000)
}

df = pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (1000, 4)
#         date  sales region product
# 0 2023-01-01    784   West       C
# 1 2023-01-02    199  South       C
# 2 2023-01-03    832   West       C
# 3 2023-01-04    756  North       A
# 4 2023-01-05    227  North       B

# %%
# Initialize the agent
agent = PlotAgent()
agent.set_df(df)

# %%
# Create a line chart showing sales over time, colored by region
response = agent.process_message("Create a line chart showing sales over time, colored by region")
fig = agent.get_figure()
fig.show()

# %%
# Interactively update the plot
response = agent.process_message("Can you add a title 'Sales Trends by Region' and smooth the lines by making them a 7 day moving average?")
fig = agent.get_figure()
fig.show()

# %%
# Add a dark mode theme
response = agent.process_message("can you make the plot have a dark mode sort of theme?")
fig = agent.get_figure()
fig.show()

# %%
# Make a 2x2 sub plot one for each region
response = agent.process_message("can we make a 2x2 sub plot one for each region? make sure to have 4 seperate plots")
fig = agent.get_figure()
fig.show()

# %%
print(agent.generated_code)
# Out:
# import pandas as pd
# import plotly.graph_objects as go
# from plotly.subplots import make_subplots
#
# # Calculate the 7-day moving average for sales
# # We will group by region and apply the rolling function to smooth the sales data
# # First, we need to ensure the data is sorted by date
#
# df = df.sort_values(by='date')
# df['sales_moving_avg'] = df.groupby('region')['sales'].transform(lambda x: x.rolling(window=7, min_periods=1).mean())
#
# # Create a 2x2 subplot for each region
# regions = df['region'].unique()  # Get unique regions
# fig = make_subplots(rows=2, cols=2, subplot_titles=regions)
#
# # Add a line for each region in the respective subplot
# for i, region in enumerate(regions):
#     row = i // 2 + 1  # Determine the row number (1 or 2)
#     col = i % 2 + 1   # Determine the column number (1 or 2)
#     region_data = df[df['region'] == region]  # Filter data for the current region
#     fig.add_trace(
#         go.Scatter(x=region_data['date'], y=region_data['sales_moving_avg'], mode='lines', name=region),
#         row=row, col=col
#     )
#
# # Update layout for better readability with a dark theme
# fig.update_layout(
#     title='Sales Trends by Region',
#     xaxis_title='Date',
#     yaxis_title='7-Day Moving Average Sales',
#     template='plotly_dark'  # Set the template to dark mode
# )
#
# # Define the plot title and summary
# plot_title = 'Sales Trends by Region'
# plot_summary = 'This figure contains four subplots, each representing the 7-day moving average of sales trends for a specific region. This layout allows for easy comparison of sales trends across different regions.'
